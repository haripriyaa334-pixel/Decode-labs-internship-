# %% [markdown]
# <a href="https://colab.research.google.com/github/haripriyaa334-pixel/Decode-labs-internship-/blob/main/Decodeproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1df81f9d-945a-4377-b6ce-dffa4d15c0d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1df81f9d-945a-4377-b6ce-dffa4d15c0d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data= pd.read_excel("Dataset for Data Analytics.xlsx")

# %%
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data.fillna("null",inplace=True)
data.columns=data.columns.str.lower()

# %%
print(type(data))
print(data.shape if hasattr(data, 'shape') else "No shape")
print(data[:5] if not hasattr(data, 'head') else data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (891, 14)
#      orderid       date customerid  product  quantity  unitprice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   shippingaddress paymentmethod orderstatus trackingnumber  itemsincart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   couponcode referralsource  totalprice
# 0     SAVE10      Instagram     2853.10
# ...

# %%
data['date']=pd.to_datetime(data['date'])

# %%
data.head()
# Out:
#      orderid       date customerid  product  quantity  unitprice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   shippingaddress paymentmethod orderstatus trackingnumber  itemsincart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   couponcode referralsource  totalprice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
data.tail()
# Out:
#         orderid       date customerid  product  quantity  unitprice  \
# 1194  ORD201194 2023-11-19     C29885  Printer         3     189.44
# 1195  ORD201195 2024-06-20     C21126     Desk         1     107.04
# 1197  ORD201197 2023-07-13     C79674   Tablet         2     436.84
# 1198  ORD201198 2024-08-22     C64753    Chair         4     262.52
# 1199  ORD201199 2023-06-11     C57502   Tablet         4     560.58
#
#      shippingaddress paymentmethod orderstatus trackingnumber  itemsincart  \
# 1194     725 Main St          Cash     Pending    TRK62067865            4
# 1195     392 Main St   Credit Card   Cancelled    TRK38009181            6
# 1197     275 Main St        Online   Delivered    TRK88039356            2
# 1198     509 Main St    Debit Card   Cancelled    TRK71683331            4
# 1199     201 Main St     Gift Card    Returned    TRK51116746            6
#
#      couponcode referralsource  totalprice
# 1194   FREESHIP          Email      568.32
# ...

# %%
data.describe()
# Out:
#                                 date    quantity   unitprice  itemsincart  \
# count                            891  891.000000  891.000000   891.000000
# mean   2024-03-25 05:34:32.727272704    2.911336  360.596835     5.459035
# min              2023-01-01 00:00:00    1.000000   11.390000     1.000000
# 25%              2023-08-16 00:00:00    2.000000  189.345000     4.000000
# 50%              2024-03-23 00:00:00    3.000000  371.290000     5.000000
# 75%              2024-11-10 00:00:00    4.000000  526.445000     7.000000
# max              2025-06-30 00:00:00    5.000000  699.930000    10.000000
# std                              NaN    1.414212  196.752386     2.277209
#
#         totalprice
# count   891.000000
# mean   1057.643715
# min      11.390000
# 25%     415.785000
# 50%     819.500000
# 75%    1581.135000
# max    3456.400000
# std     822.703899

# %%
num_cols = data.select_dtypes(include='number').columns
data[num_cols] = data[num_cols].round(0)

# %%
data.head()
# Out:
#      orderid       date customerid  product  quantity  unitprice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5      571.0
# 1  ORD200001 2024-08-23     C75739    Phone         2      151.0
# 2  ORD200002 2024-02-27     C81728   Tablet         5      551.0
# 3  ORD200003 2023-10-15     C33540    Chair         1      273.0
# 4  ORD200004 2025-05-08     C81840  Printer         4      626.0
#
#   shippingaddress paymentmethod orderstatus trackingnumber  itemsincart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   couponcode referralsource  totalprice
# 0     SAVE10      Instagram      2853.0
# 1     SAVE10       Referral       303.0
# ...

# %%
data.to_excel("cleanedD.xlsx",index=False)

# %%
files.download("cleanedD.xlsx")
